# %% [markdown]
# ## Movie review tagging model testing - Data Science

# %% [markdown]
# ### Data preparation

# %% [markdown]
# #### Preprocessed dataset reading

# %%
import pandas as pd

df = pd.read_csv('data/Preprocessed_Dataset.csv')
df.head()
# Out:
#                                              Reviews  Acting  Plot  Scene  \
# 0  Xem buồn ngủ lắm 1. nội dung k có gì đặc sắc 2...       1     1      1
# 1  Phim hay, coi cuốn từ đầu tới cuối nha. Phim c...       0     1      1
# 2                Nhiều sr fim giống nên xem hơi nhàm       0     0      0
# 3  Phim đáng xem, xứng danh bom tấn. Các cảnh qua...       1     0      1
# 4  Cài cắm nhiều nút thắt “đòn bẫy” xuyên suốt, t...       0     1      0
#
#    Comedy  Touching                               Preprocessed Reviews
# 0       0         0  xem buồn_ngủ 1 nội_dung không đặc_sắc 2 hình_ả...
# 1       1         0  phim hay coi cuốn từ đầu tới cuối phim nhiều ý...
# 2       0         0                  nhiều mùa phim giống xem hơi nhàm
# 3       0         0  phim đáng xem xứng danh bom tấn các cảnh quay ...
# 4       0         0  cài cắm nhiều nút thắt đòn bẫy xuyên suốt tác_...

# %%
import joblib

review_tagger_model = joblib.load('Review_Tagger_Model.pkl')
review_tagger_model
# Out:
# BinaryRelevance(classifier=RandomForestClassifier(), require_dense=[True, True])

# %%
input_string = 'Xem buồn ngủ. Nội dung không đặc sắc. Đc cái na9 nu9 duyên dáng, làm cả rạp cười xỉuuu 🤣🤣'

# %%
from Preprocessing import preprocess_string

input_string = preprocess_string(input_string)
input_string
# Out:
# 'xem buồn_ngủ nội_dung không đặc_sắc được cái na9_nu9 duyên_dáng làm cả rạp cười xỉu'

# %%
from Vectorizing import vectorizing_string

input_features = vectorizing_string(input_string)
input_features.shape
# Out:
# (1, 1000)

# %%
prediction = review_tagger_model.predict(input_features).toarray()

all_tags = ['Acting', 'Plot', 'Scene', 'Comedy', 'Touching']

print('Predicted labels:', prediction)
print('Predicted tags:', [tag for idx, tag in enumerate(all_tags) if prediction[0][idx]])
# Out:
# Predicted labels: [[0. 1. 0. 1. 0.]]
# Predicted tags: ['Plot', 'Comedy']
